# %%
import folium
c= folium.Map(location=[46.001989 , 6.780061])
folium.Marker([46.021067,6.768492],popup="Chalet du Lignon").add_to(c)
folium.Marker([46.004506,6.791264],popup="refuge Alfred Wills").add_to(c)
folium.Marker([45.992160,6.799769],popup="Lac d'Anterne").add_to(c)
folium.Marker([45.974984,6.800455],popup="refuge de Moëde").add_to(c)
c.save('jailacarterando.html')
